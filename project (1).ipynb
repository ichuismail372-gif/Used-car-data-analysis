# %% [markdown]
# ## CAR DETAILS ANALYSIS USING PYTHON

# %% [markdown]
# ### Aim
#  - this project analyzes car data to understand price,mileage,fuel type and other features.

# %% [markdown]
# #Statement
#
#
# The objective of this projectis to analyse a dataset of used cars to understand the key factors that influence the selling price. The dataset includes features such as year'fueltype,transmission,ownership,mileage,engine capacity,and maximoum power
#
#
# The goal is to build a model that can accurately predict the selling price of a car based on these features,while also identifying the most important variables affecting price. This will help in making better pricing decisions for buyers and sellers in the used car market

# %% [markdown]
# #### Day 1

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("car.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# ### Inspect Data

# %%
df.head(5)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# -  Displays the first five rows of data frame

# %%
df.tail(5)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %% [markdown]
# - displays the last 5 rows of the frame

# %% [markdown]
# ## Random

# %%
df.sample()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 1160  Chevrolet Sail LT ABS  2015         480000      80000  Diesel
#
#      seller_type transmission         owner    mileage   engine max_power  \
# 1160  Individual       Manual  Second Owner  22.1 kmpl  1248 CC    74 bhp
#
#               torque  seats
# 1160  190Nm@ 1750rpm    5.0

# %% [markdown]
# - dislays sample 1 raw of the frame

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# - 8 columns are perfect:name,year,selling_price,km_driven,fuel,transmission,owner,selling_type
# - 5 columns need cleaning:mileage,engine,max_power,torque,seats

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# - total columns=13

# %%
df.shape
# Out:
# (8128, 13)

# %% [markdown]
# - this dataset has 8128 rows and 13 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %% [markdown]
# * total 13 columns
# * total 8128 entries
# * memory usage=825.6 KB
# * 5 columns have missing values:milege,engine,max_power,torque,seats
# * data type issue: mileage, engine , max_power,torque are 'str' but should be numeric

# %% [markdown]
# ## Selecting colums

# %%
#single column
df['name']
# Out:
# 0             Maruti Swift Dzire VDI
# 1       Skoda Rapid 1.5 TDI Ambition
# 2           Honda City 2017-2020 EXi
# 3          Hyundai i20 Sportz Diesel
# 4             Maruti Swift VXI BSIII
#                     ...
# 8123               Hyundai i20 Magna
# 8124           Hyundai Verna CRDi SX
# 8125          Maruti Swift Dzire ZDi
# 8126                 Tata Indigo CR4
# 8127                 Tata Indigo CR4
# Name: name, Length: 8128, dtype: object

# %%
df[['name','year']]
# Out:
#                               name  year
# 0           Maruti Swift Dzire VDI  2014
# 1     Skoda Rapid 1.5 TDI Ambition  2014
# 2         Honda City 2017-2020 EXi  2006
# 3        Hyundai i20 Sportz Diesel  2010
# 4           Maruti Swift VXI BSIII  2007
# ...                            ...   ...
# 8123             Hyundai i20 Magna  2013
# 8124         Hyundai Verna CRDi SX  2007
# 8125        Maruti Swift Dzire ZDi  2009
# 8126               Tata Indigo CR4  2013
# 8127               Tata Indigo CR4  2013
#
# [8128 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df[['name','year','selling_price']]
# Out:
#                               name  year  selling_price
# 0           Maruti Swift Dzire VDI  2014         450000
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2         Honda City 2017-2020 EXi  2006         158000
# 3        Hyundai i20 Sportz Diesel  2010         225000
# 4           Maruti Swift VXI BSIII  2007         130000
# ...                            ...   ...            ...
# 8123             Hyundai i20 Magna  2013         320000
# 8124         Hyundai Verna CRDi SX  2007         135000
# 8125        Maruti Swift Dzire ZDi  2009         382000
# 8126               Tata Indigo CR4  2013         290000
# 8127               Tata Indigo CR4  2013         290000
#
# [8128 rows x 3 columns]

# %% [markdown]
# #### Day 2

# %% [markdown]
# ## Filtering the data

# %%
df[df['year']>2010]
# Out:
#                                       name  year  selling_price  km_driven  \
# 0                   Maruti Swift Dzire VDI  2014         450000     145500
# 1             Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 5            Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 8                         Toyota Etios VXD  2011         350000      90000
# 9     Ford Figo Diesel Celebration Edition  2013         200000     169000
# ...                                    ...   ...            ...        ...
# 8121     Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122            Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                     Hyundai i20 Magna  2013         320000     110000
# 8126                       Tata Indigo CR4  2013         290000      25000
# 8127                       Tata Indigo CR4  2013         290000      25000
#
# ...

# %% [markdown]
# - After filtering ,there are 6651 rows and 13 columns remainng

# %%
df[df['fuel']=='Petrol']
# Out:
#                                    name  year  selling_price  km_driven  \
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 11                        Maruti Zen LX  2005          92000     100000
# ...                                 ...   ...            ...        ...
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8123                  Hyundai i20 Magna  2013         320000     110000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - After fitering ,the dataset has 3631 rows and 13 columns, and only petrol cars are present in the fuel column

# %%
df[df['owner']=='First Owner']
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 6      Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# ...                             ...   ...            ...        ...     ...
# 8120        Hyundai Santro Xing GLS  2008         120000     191000  Petrol
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# - After filtering for 1st owner only ,the daataset has 5289 rows and 13 columns

# %%
df[df['selling_price']>2000000]
# Out:
#                                     name  year  selling_price  km_driven  \
# 41    Jeep Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 82                BMW X1 sDrive20i xLine  2016        2500000      30000
# 131           Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 132                        Lexus ES 300h  2019        5150000      20000
# 133       Jaguar XF 2.0 Diesel Portfolio  2017        3200000      45000
# ...                                  ...   ...            ...        ...
# 7873          BMW X4 M Sport X xDrive20d  2019        5500000       8500
# 7876               Volvo V40 D3 R-Design  2018        2475000       2000
# 7922          Skoda Kodiaq 2.0 TDI Style  2018        2800000      40000
# 7930       Volvo S90 D4 Inscription BSIV  2019        5500000      17000
# 7931  Ford Endeavour 2.2 Titanium AT 4X2  2016        2100000      85000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - After filtering for selling_price above 20,00,000,the dataset has 358rows ans 13 colunms.the row reduces because only 358 cars have sellinfprice greater than 20 lakhs

# %%
df[(df['transmission']=='Automatic')&(df["seller_type"]=="Dealer")]
# Out:
#                                      name  year  selling_price  km_driven  \
# 44              Maruti Swift Dzire VXi AT  2018         675000      23300
# 49             Mercedes-Benz B Class B180  2014        1450000      27800
# 55    Toyota Innova Crysta 2.8 ZX AT BSIV  2016        1650000     127700
# 57             Audi A6 2.0 TDI Technology  2013        1750000      33900
# 58        Toyota Corolla Altis 1.8 VL CVT  2018        1590000      25000
# ...                                   ...   ...            ...        ...
# 8045    Renault Duster RXZ 110PS AMT BSIV  2017         750000      20171
# 8052               Honda CR-V 2.4L 4WD AT  2012         750000      50171
# 8057                 Honda Accord 2.4 A/T  2013         580000      50000
# 8058              Audi A3 40 TFSI Premium  2017        1689999       8000
# 8063       Hyundai Creta 1.6 SX Automatic  2016         890000      40000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - after filtering for automatic cars sold by dealers ,there are 459 rows and 13 columns

# %%
#selecting rows
df.iloc[12]
# Out:
# name             Maruti Swift Dzire VDi
# year                               2009
# selling_price                    280000
# km_driven                        140000
# fuel                             Diesel
# seller_type                  Individual
# transmission                     Manual
# owner                      Second Owner
# mileage                       19.3 kmpl
# engine                          1248 CC
# max_power                      73.9 bhp
# torque                   190Nm@ 2000rpm
# seats                               5.0
# Name: 12, dtype: object

# %% [markdown]
# - row at index 12 shows a 2009 maruti swift dzire VDi

# %%
df.iloc[3:12]
# Out:
#                                     name  year  selling_price  km_driven  \
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
#
#       fuel seller_type transmission         owner     mileage   engine  \
# 3   Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4   Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
# ...

# %% [markdown]
# - this selects the rows from position 3 up to 11 ,giving 9 rows in total

# %%
#loc method
df.loc[500,'mileage']
# Out:
# '17.5 kmpl'

# %%
df.loc[450,'km_driven']
# Out:
# np.int64(25000)

# %% [markdown]
# ## Rename column

# %%
df.rename(columns={"selling_price":"price"},inplace=True)
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage   engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - The column selling_price has been renamed to price in the dataset

# %% [markdown]
# #### Value count

# %%
print("value in owner column")
df['owner'].value_counts()
# Out:
# value in owner column
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# - most cars in the dataset are 1st owner at 5289 ,and the least are test drive cars at 5

# %%
print("values seller_type column")
df['seller_type'].value_counts()
# Out:
# values seller_type column
# seller_type
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: count, dtype: int64

# %% [markdown]
# - individual sellers have the highest count with 6766 cars

# %%
print("values fuel column")
df['fuel'].value_counts()
# Out:
# values fuel column
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %% [markdown]
# - diesel is the most commen fuel type  with 4402 cars

# %%
print("values transmission column")
df['transmission'].value_counts()
# Out:
# values transmission column
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %% [markdown]
# - there are 7078 manual cars 1050  automatic cars .most cars are malnual

# %% [markdown]
# #### Day 3

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### clean numerical column with characters

# %%
# remove text units and convert to numbers
df['engine']=pd.to_numeric(
    df['engine']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage  engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248.0      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498.0  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497.0      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396.0      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298.0    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - Text was removed from the engine column and it was changed to numbers

# %%
df['max_power']=pd.to_numeric(
    df['max_power']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage  engine  max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248.0      74.00
# 1       Manual  Second Owner  21.14 kmpl  1498.0     103.52
# 2       Manual   Third Owner   17.7 kmpl  1497.0      78.00
# 3       Manual   First Owner   23.0 kmpl  1396.0      90.00
# 4       Manual   First Owner   16.1 kmpl  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - Text was removed from the max_power column and it was changed to numbers

# %%
df['mileage']=pd.to_numeric(
    df['mileage']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  \
# 0       Manual   First Owner    23.40  1248.0      74.00
# 1       Manual  Second Owner    21.14  1498.0     103.52
# 2       Manual   Third Owner    17.70  1497.0      78.00
# 3       Manual   First Owner    23.00  1396.0      90.00
# 4       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# ...

# %% [markdown]
# - Text was removed from the mileage column and it was changed to numbers

# %%
# df['torque']=pd.to_numeric(
#     df['torque']
#     .astype(str)
#     .str.replace(r'[^0-9,-]','',regex=True)
#     .replace('',None),
#     errors='coerce'
# )
# this is not working

# %% [markdown]
# - The torque cleaning code failed. text is stil there in the torque column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8128 non-null   object
#  1   year          8128 non-null   int64
#  2   price         8128 non-null   int64
#  3   km_driven     8128 non-null   int64
#  4   fuel          8128 non-null   object
#  5   seller_type   8128 non-null   object
#  6   transmission  8128 non-null   object
#  7   owner         8128 non-null   object
#  8   mileage       7907 non-null   float64
#  9   engine        7907 non-null   float64
#  10  max_power     7912 non-null   float64
#  11  torque        7906 non-null   object
#  12  seats         7907 non-null   float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 825.6+ KB

# %% [markdown]
# - the data set has 8128 cars and 13 columns.engine ,mileage ,and max_power are cleaned to number, but torque is still text.5 columns have missing values

# %%
df.columns
# Out:
# Index(['name', 'year', 'price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# - 13 columns

# %% [markdown]
# #### Drop column

# %%
df.drop(columns=['torque'],inplace=True)

# %%
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00    5.0
# 1       Manual  Second Owner    21.14  1498.0     103.52    5.0
# 2       Manual   Third Owner    17.70  1497.0      78.00    5.0
# 3       Manual   First Owner    23.00  1396.0      90.00    5.0
# 4       Manual   First Owner    16.10  1298.0      88.20    5.0

# %%
df.shape
# Out:
# (8128, 12)

# %% [markdown]
# - torque column was removed .now there are 12 columns and the cleaned data is visible

# %% [markdown]
# #### Handling missing values

# %%
df.isnull().sum()
# Out:
# name              0
# year              0
# price             0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage         221
# engine          221
# max_power       216
# seats           221
# dtype: int64

# %% [markdown]
# - 12 columns remain .4 columns have missing data: mileage ,engine,max_power ,seats

# %% [markdown]
# ## Finding missing values

# %% [markdown]
# ##### - Numericls-fill with median
#       missing values in numeric columns will be filled with medien
# ##### - Categorical - fill with mode
#       missing values in categorical columns will be filled with mode

# %%
df['seats']=df['seats'].fillna(df['seats'].median())

# %%
df['mileage']=df['mileage'].fillna(df['mileage'].median())

# %%
df['engine']=df['engine'].fillna(df['engine'].median())

# %%
df['max_power']=df['max_power'].fillna(df['max_power'].median())

# %% [markdown]
# - the missing value in seats,mileage,engine,and max_power columns were filled using the median of each column

# %%
df.isnull().sum()
# Out:
# name            0
# year            0
# price           0
# km_driven       0
# fuel            0
# seller_type     0
# transmission    0
# owner           0
# mileage         0
# engine          0
# max_power       0
# seats           0
# dtype: int64

# %% [markdown]
# - all missing values are filled .no nulla left

# %%
df.shape
# Out:
# (8128, 12)

# %% [markdown]
# - dataset shape is 8128 rows and 12 columns

# %%
df['seats']=df['seats'].astype(int)

# %%
df.dtypes
# Out:
# name             object
# year              int64
# price             int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# mileage         float64
# engine          float64
# max_power       float64
# seats             int64
# dtype: object

# %% [markdown]
# - the seats changed to int64.all data types are now correct.data cleaning is complete

# %%
df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %% [markdown]
# ## Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %% [markdown]
# - There are 1202 duplicate rows present in dataset

# %%
print('Before:',df.shape)
df=df.drop_duplicates()
print('After:',df.shape)
# Out:
# Before: (8128, 12)
# After: (6926, 12)

# %% [markdown]
# - 1202 duplicate rows were removed .dataset now has 6929unique rows and 12 columns with no duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - NO dulicate rows remain .data is clean with 0 duplicates

# %% [markdown]
# #### Day 4

# %% [markdown]
# ## Verifying data cleaning

# %%
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %%
df.tail(5)
# Out:
#                                    name  year   price  km_driven    fuel  \
# 8121  Maruti Wagon R VXI BS IV with ABS  2013  260000      50000  Petrol
# 8122         Hyundai i20 Magna 1.4 CRDi  2014  475000      80000  Diesel
# 8123                  Hyundai i20 Magna  2013  320000     110000  Petrol
# 8124              Hyundai Verna CRDi SX  2007  135000     119000  Diesel
# 8125             Maruti Swift Dzire ZDi  2009  382000     120000  Diesel
#
#      seller_type transmission                 owner  mileage  engine  \
# 8121  Individual       Manual          Second Owner    18.90   998.0
# 8122  Individual       Manual          Second Owner    22.54  1396.0
# 8123  Individual       Manual           First Owner    18.50  1197.0
# 8124  Individual       Manual  Fourth & Above Owner    16.80  1493.0
# 8125  Individual       Manual           First Owner    19.30  1248.0
#
#       max_power  seats
# 8121      67.10      5
# 8122      88.73      5
# 8123      82.85      5
# ...

# %%
df.shape
# Out:
# (6926, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6926 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          6926 non-null   object
#  1   year          6926 non-null   int64
#  2   price         6926 non-null   int64
#  3   km_driven     6926 non-null   int64
#  4   fuel          6926 non-null   object
#  5   seller_type   6926 non-null   object
#  6   transmission  6926 non-null   object
#  7   owner         6926 non-null   object
#  8   mileage       6926 non-null   float64
#  9   engine        6926 non-null   float64
#  10  max_power     6926 non-null   float64
#  11  seats         6926 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 703.4+ KB

# %%
df.columns
# Out:
# Index(['name', 'year', 'price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %% [markdown]
# ## Saving the data

# %% [markdown]
#  #### The survivors to a new csv file

# %%
df.to_csv ('car.csv_cleaned',index=False)

# %% [markdown]
# - Cleaned data save as car.csv_cleaned without row index

# %% [markdown]
# #### Load the data

# %%
df_new=pd.read_csv("car.csv_cleaned")
df
# Out:
#                                    name  year   price  km_driven    fuel  \
# 0                Maruti Swift Dzire VDI  2014  450000     145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel
# 2              Honda City 2017-2020 EXi  2006  158000     140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel
# 4                Maruti Swift VXI BSIII  2007  130000     120000  Petrol
# ...                                 ...   ...     ...        ...     ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013  260000      50000  Petrol
# 8122         Hyundai i20 Magna 1.4 CRDi  2014  475000      80000  Diesel
# 8123                  Hyundai i20 Magna  2013  320000     110000  Petrol
# 8124              Hyundai Verna CRDi SX  2007  135000     119000  Diesel
# 8125             Maruti Swift Dzire ZDi  2009  382000     120000  Diesel
#
#      seller_type transmission                 owner  mileage  engine  \
# ...

# %% [markdown]
# - loading the cleaned data from car.csv_cleaned to confirm the save worked

# %%
df_new.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %% [markdown]
# ## Summary statistics

# %%
df_new.columns
# Out:
# Index(['name', 'year', 'price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %% [markdown]
# ## Average(mean) , Medien & Mode

# %%
print("year  -  ",df['year'].mean())
print("year  -  ",df['year'].median())
print("year  -  ",df['year'].mode())
# Out:
# year  -   2013.4203003176438
# year  -   2014.0
# year  -   0    2017
# Name: year, dtype: int64

# %% [markdown]
# - Calculated average ,madien And mode of  car manufacturing years

# %%
print("price  -  ",df['price'].mean())
print("price  -  ",df['price'].median())
print("price  -  ",df['price'].mode())
# Out:
# price  -   517270.6784579844
# price  -   400000.0
# price  -   0    300000
# Name: price, dtype: int64

# %% [markdown]
# - this code calculats the mean,median and mode of the car price

# %%
print("mileage  -  ",df['mileage'].median())
print("mileage  -  ",df['mileage'].median())
print("mileage  -  ",df['mileage'].mode())
# Out:
# mileage  -   19.3
# mileage  -   19.3
# mileage  -   0    19.3
# Name: mileage, dtype: float64

# %% [markdown]
# - this code calculats the mean,median and mode of the car mileage

# %%
print("engine  -  ",df['engine'].mean())
print("engine  -  ",df['engine'].median())
print("engine  -  ",df['engine'].mode())
# Out:
# engine  -   1425.3987871787467
# engine  -   1248.0
# engine  -   0    1248.0
# Name: engine, dtype: float64

# %% [markdown]
#  - this code calculats the mean,median and mode of the car engine

# %%
print("seats  -  ",df['seats'].mean())
print("seats  -  ",df['seats'].median())
print("seats  -  ",df['seats'].mode())
# Out:
# seats  -   5.421599768986428
# seats  -   5.0
# seats  -   0    5
# Name: seats, dtype: int64

# %% [markdown]
#  - this code calculats the mean,median and mode of the car seats

# %% [markdown]
# ## Standerd deviation

# %%
df.select_dtypes(include='number').mode()
# Out:
#    year   price  km_driven  mileage  engine  max_power  seats
# 0  2017  300000     120000     19.3  1248.0       74.0      5

# %%
df.select_dtypes(include='number').std()
# Out:
# year              4.078286
# price        519766.985985
# km_driven     58358.095175
# mileage           3.987976
# engine          487.026967
# max_power        31.310612
# seats             0.972171
# dtype: float64

# %% [markdown]
# - Calculated standard deviation for all numeric columns to measure data spread

# %%
df.describe()
# Out:
#               year         price     km_driven      mileage       engine  \
# count  6926.000000  6.926000e+03  6.926000e+03  6926.000000  6926.000000
# mean   2013.420300  5.172707e+05  7.399568e+04    19.460345  1425.398787
# std       4.078286  5.197670e+05  5.835810e+04     3.987976   487.026967
# min    1983.000000  2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000  2.500000e+05  4.000000e+04    16.950000  1197.000000
# 50%    2014.000000  4.000000e+05  7.000000e+04    19.300000  1248.000000
# 75%    2017.000000  6.335000e+05  1.000000e+05    22.320000  1498.000000
# max    2020.000000  1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  6926.000000  6926.000000
# mean     87.556583     5.421600
# std      31.310612     0.972171
# min       0.000000     2.000000
# 25%      68.000000     5.000000
# 50%      81.860000     5.000000
# 75%      99.000000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# - gets full statistical summary of all numeric columns in one short

# %% [markdown]
# #### Inside the date

# %% [markdown]
# - year- cars range from 1983 to 2020,most are 2010
# - seats- range 2 to 14, but most cars have 5 seats
# - outliers are present in price,km_driven,mileage,max_power
# - most cars have 5 seatss
# - average km driven is arount 73,000km
# - price have large varition (13k to 1 crore)

# %%
df.describe(include=object)
# Out:
#                           name    fuel seller_type transmission        owner
# count                     6926    6926        6926         6926         6926
# unique                    2058       4           3            2            5
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                       118    3755        6218         6342         4242

# %% [markdown]
# - most used fuel is diesel
# - sellertype has 3 categores
# - ower type has 5 categories , most are 1st owner
# - name column has 2058 unique car models -high variety
# - transmission has only 2 types
# - most sellers are individuals
# - most common car model is maruti swift Dzire VDI

# %% [markdown]
# ## Day 5

# %% [markdown]
# ## Data visualization

# %% [markdown]
# #### Univariate analysis
# - histogram,kde,box - numerical
# - cout_pie-categorical

# %% [markdown]
# #### Bivariate
# - barplot - category va numerical
# - line plot - (time series)and scatter - numerical va numerical

# %% [markdown]
# #### Multivariate
# - heatmap - correlation
# - pair plot - numerical

# %% [markdown]
# ###  1.Histrogram
# - Distribution of numerical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
sns.histplot(data=df_new,x="mileage",bins=20,color="blue")
plt.title("Distribution of mileage")
plt.show()

# %% [markdown]
# - most car have mileage b/w 15 to 25 kmpl
# - peak is around 18 to 22 kmpl

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
sns.histplot(data=df_new,x="year",bins=20,color="red")
plt.title("Distribution of year")
plt.show()

# %% [markdown]
# - graph: histogram of car manufacturing years
# - peak years:2017 - 2018 highest count  (1400 cars)
# - low years :before 2000 - almost no car
# - reason: the 2nd hand market has more recent cars.old cars are  rarely listed

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
sns.histplot(data=df_new,x="engine",bins=20,color="pink")
plt.title("engine of the car")
plt.show()

# %% [markdown]
# - highest count: 1200-1500
# - lowest count:,1000cc and.3000cc engnes very few cars
# - reason: 1200-1500 cc gives good mileage+power+low price,so most people prefer it

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
sns.histplot(data=df_new,x="max_power",bins=10,color="black")
plt.title("max_power of car")
plt.show()

# %% [markdown]
# - peak range:50-100 bhp - highest count - 3000cars
# - rare range .200bhp -very few cars
# - reason: low mid power cars are affordable and fuel efficient,so they dominate the market

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4)) #fiquer size adjest
plt.title("price of the car")
sns.histplot(data=df_new,x="price",bins=20,color="yellow")
plt.title("price of the car")
plt.show()

# %% [markdown]
# - low-price cars have high count
# - high-price cars have low count
# - so price increases ,count decreases
# - most poeple  prefer affortable cars,their number is high
# - expensive cars are less common because fewer poeple can affort them

# %% [markdown]
# ### Kde plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) #fiquer size adjest

sns.histplot(data=df_new,x="price",bins=20,color="yellow",kde=True)
plt.title("price of the car")
plt.show()

# %% [markdown]
# - peak range: most cars fall b/w 0-10 lakh -count 4500,KDE peak is here
# - tail: prices above 20 lakh have very  few cars
# - data is right-skewed because cheap cars dominate the used car market

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) #fiquer size adjest

sns.histplot(data=df_new,x="max_power",bins=20,color="black",kde=True)
plt.title("max_power of the car")
plt.show()

# %% [markdown]
# - peak range:most cars have max power b/w 60 to 100bhp
# - low count: cars with > 200bhp are very rare
# - 60 - 100 bhp cars use less fuel and cost less money.so most people buy them .cars with high power are costly ,so vety few people buy them

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) #fiquer size adjest

sns.histplot(data=df_new,x="engine",bins=20,color="pink",kde=True)
plt.title("engine of the car")
plt.show()

# %% [markdown]
# - commen range :1200-1500cc - most cars
# - rare range :.3000cc - very few cars
# - reason: 1200- 1500 cc engines give good mileage and enough power.they are also cheap.so most people buy these cars .big  engines are costly and use more fuel,so people buy less

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) #fiquer size adjest

sns.histplot(data=df_new,x="year",bins=20,color="red",kde=True)
plt.title("year of the car")
plt.show()

# %% [markdown]
# - most cars:made  in 2012 to2018
# - very few cars : made before year 2000
# - reason: people sell new cars more.old cars are not used much

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) #fiquer size adjest

sns.histplot(data=df_new,x="mileage",bins=20,color="blue",kde=True)
plt.title("mileage of the car")
plt.show()

# %% [markdown]
# - most cars:give 18 to 22 km/l mileage
# - very few cars : gives less than 10 km/l
# - reason= most normal cars give less .new hybrid cars give more

# %% [markdown]
# ###  2.Box type

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df_new,x="engine",color="green")
# Out:
# <Axes: xlabel='engine'>

# %% [markdown]
# - box: half the cars have engine 1200-1500 cc
# - middle line:  average engine is -1300 cc
# - dot on right:some cars have big engine 2000+cc. these are rare and costly cars.they are outlierrs

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df_new,x="mileage",color="blue")
# Out:
# <Axes: xlabel='mileage'>

# %% [markdown]
# - box: half the cars give mileage 18-23 km/l
# - middle line: average mileage is 20 km/l
# - dots : few cars give very high 30+ km/l .this are special cases

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df_new,x="year",color="pink")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# - box:half the cars are from 2010 -2017
# - middle line : average year is 2014
# - dots :lots of dots on left side from 1985 to 2000.these are very old cars

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df_new,x="max_power",color="black")
# Out:
# <Axes: xlabel='max_power'>

# %% [markdown]
# - box:half the cars have power 70-100bhp- most common cars
# - middle line:average power is -85 bhp
# - outliers : many dots from 150 -400bhp on right -high-power sports cars.one dot near 0 bhp on left -maybe wrong data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df_new,x="price",color="yellow")
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# - box: half the cars cost 5-10 lakh -most commen price range
# - middle line: average price is 7 to 8 lakh
# - outliers : lots of dots from 20 lakh to 1 crore on right- very costly laxury cars

# %% [markdown]
# ### Count plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='fuel',data=df_new)
plt.title("count of fuel types")
plt.show()

# %% [markdown]
# - diesel: highest count with - 3700 cars- most common fuel type here
# - petrol:second highest with - 3000 cars - also very common
# - LPG&CNG:very few cars <100 each- rare in this dateset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='transmission',data=df_new)
plt.title("transmission count")
plt.show()

# %% [markdown]
# - manual:6300 cars are manual-most common type
# - automatic : only 700 cars are automatic-very few
# - ratio:for every 9 manual cars ,theres only 1 autmatic car

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='owner',data=df_new)
plt.title("owner count")
plt.show()

# %% [markdown]
# - first owner:4200 cars are 1st owner-most cars in dataset are sold by 1st owner
# - second owner :2000 cars are second owner - already once
# - third/4th owner: very few - 600 third owner ,300 fourth&above

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='seller_type',data=df_new)
plt.title("seller_type count")
plt.show()

# %% [markdown]
# .Individual:6200 cars sold by individual-most common seller
#
# .dealer:only 700 cars from dealers -much less
#
# .trustmark dealer-almost none

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='fuel',hue='transmission',data=df_new)
plt.title("fuel type vs transmission")
plt.show()

# %% [markdown]
# .Manual are more affordable amd widely preffered in price -sensitive markets

# %% [markdown]
# ## Day 6

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x=df['transmission'],y=df['engine'])
# Out:
# <Axes: xlabel='transmission', ylabel='engine'>

# %% [markdown]
# .automatic cars come with bigger engines.manuals cars use smaller engines to keep cost and mileage better
#
# .engine size depends on transmission

# %%
sns.barplot(x=df['fuel'],y=df['price'])
# Out:
# <Axes: xlabel='fuel', ylabel='price'>

# %% [markdown]
# .Diesel cars have highest price
#
# .fuel type strongly affects price

# %%
sns.barplot(x=df['transmission'],y=df['price'])
# Out:
# <Axes: xlabel='transmission', ylabel='price'>

# %% [markdown]
# .Automatic cars are premium and cost 9 lakh more on average than budget manual cars

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.scatterplot(x='km_driven',y='price',data=df_new)
plt.title("price vs kilometers driven")
plt.xlabel("kilometers driven")
plt.ylabel("price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# . When a car is driven more,its usually goes down
#
# .Kilometers driven is very important to decide a car's price
#
# .For better resale value cars with low kelometers are best,expensive car lose value faster if used more

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.scatterplot(x='mileage',y='price',data=df_new)
plt.title("price vs manufacturing year")
plt.xlabel("mileage")
plt.ylabel("price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# -Cheap cars usually give 10-30 kmpl mileage.Costly have 10-20 kmpl .High price and high mileage is very rare

# %% [markdown]
# # Heat map

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numeric_cols=df.select_dtypes(include=['float64','Int64']).corr()
sns.heatmap(numeric_cols,annot=True,cmap='coolwarm')
plt.title('correlation Heatmap')
plt.show()

# %% [markdown]
# -price increases with max_power  and engine
#
# -bigger cars have bigger engines and more seats
#
# -mileage decreases with engine size and seats
#
# -more km_driven reduces price
#
# -newer cars have higher price

# %% [markdown]
# ### price & year

# %% [markdown]
# ### - how does the manufacturing year affect the selling price of a car?

# %%
import seaborn as sns
import  matplotlib.pyplot as plt
plt.figure (figsize=(5,5))
sns.scatterplot(x='year',y='price',data=df_new)
plt.title("price as manufacturing year")
plt.xlabel("year")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ### Does automatic cars have higher priced then normal cars ?

# %%
import matplotlib.pyplot as plt
cars=['manual','automatic']
prices=[6,8]
plt.bar(cars,prices)
plt.title("manual vs automatic car price comparison")
plt.xlabel("car typle")
plt.ylabel("price")
plt.show()

# %% [markdown]
#  #### does the seller type(individual va delear)influence the selling price?

# %%
import matplotlib.pyplot as plt
seller_type=['individual','dealer']
prices=[6.5,8.0]
plt.bar(seller_type,prices)
plt.title("effect of seller_type on car price")
plt.xlabel("seller_type")
plt.ylabel("price")
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# The car dataset shows how different factors affect the selling price of cars. The most important factors are year, kilometers driven, engine power, and ownership. Newer cars usually have higher prices because they are in better condition and have more modern features. Cars with lower kilometers driven are also more valuable because they are less used.
#
# Engine capacity and maximum power also play a big role. Cars with higher power and bigger engines generally have higher prices. Fuel type also has some influence. Diesel cars often have slightly higher value because they give better mileage and are preferred for long-distance travel.
#
# Most of the cars in the dataset use manual transmission, and many are sold by individual owners instead of dealers. Cars with first ownership have better value compared to second or third owners, as they are considered more reliable.
#
# The torque column was removed from the dataset because it had inconsistent or complex values, making it difficult to analyze properly.
#
# Overall, the dataset clearly shows that car condition, performance, and usage history are the main factors that determine the price. Buyers usually prefer cars that are newer, less used, and more powerful.
